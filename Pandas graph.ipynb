# %%
import random
import numpy as np
import pandas as pd
from pandas import DataFrame , Series
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
graph1 = pd.DataFrame(np.random.randn(10 , 4).cumsum(1),
                      columns=['A','B','C','D'],
             index = np.arange(0,100,10))


plt.xlabel("This is X axis")
plt.ylabel("This is Y label")
plt.plot(graph1)
# Out:
# [<matplotlib.lines.Line2D at 0x15a2b092b38>,
#  <matplotlib.lines.Line2D at 0x15a2b092c88>,
#  <matplotlib.lines.Line2D at 0x15a2b092dd8>,
#  <matplotlib.lines.Line2D at 0x15a2b092f28>]

# %%
pd1 = DataFrame({'Name':[1,2,3,4] , 'Tname':[10,20,30,40]
               })
pd1.plot()
